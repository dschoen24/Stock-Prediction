# %%
#!pip install pandas_datareader
# Out:
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# Requirement already satisfied: requests>=2.19.0 in c:\users\user\anaconda3\lib\site-packages (from pandas_datareader) (2.24.0)
# Requirement already satisfied: lxml in c:\users\user\anaconda3\lib\site-packages (from pandas_datareader) (4.6.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\user\anaconda3\lib\site-packages (from pandas_datareader) (1.1.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (2020.1)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas_datareader) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.10)
# Installing collected packages: pandas-datareader
# Successfully installed pandas-datareader-0.10.0
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\user\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import math
import numpy as np
import os
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas_datareader as pdr
from datetime import datetime, timedelta

# %%
#Get the stock
ticker = 'DOW'
stock ="DOW"
# Time step n days, here we will use n  days historical data to predict next day closing
ts_points = 120
# train_data[0:60,0]  

today = datetime.today()
# start_date ='2016-01-01'
start_date = (today - timedelta(days=5*365) ).strftime('%Y-%m-%d')

end_date   = today.strftime('%Y-%m-%d')
stock_df = pdr.DataReader(ticker, data_source="yahoo", start=start_date, end=end_date)

# %%
# Date is an index but to be sure , let's sort
stock_df = stock_df.sort_index(ascending=True)
stock_df
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2019-03-20  53.500000  49.500000  52.750000  49.799999  2350800.0  43.397259
# 2019-03-21  50.000000  48.200001  49.990002  48.980000  1764700.0  42.682682
# 2019-03-22  49.950001  48.160000  48.799999  48.599998   844700.0  42.351536
# 2019-03-25  49.400002  48.000000  48.599998  49.150002   440900.0  42.830830
# 2019-03-26  49.750000  48.180000  49.000000  48.849998   504700.0  42.569393
# ...               ...        ...        ...        ...        ...        ...
# 2021-10-18  59.389999  57.599998  57.700001  58.950001  4660100.0  58.950001
# 2021-10-19  59.270000  58.540001  59.090000  59.189999  3650600.0  59.189999
# 2021-10-20  60.608002  58.941002  59.160000  59.889999  5875300.0  59.889999
# 2021-10-21  61.169998  57.959999  60.070000  59.259998  8916600.0  59.259998
# 2021-10-22  60.189999  58.380001  59.639999  58.400002  5889477.0  58.400002
#
# [656 rows x 6 columns]

# %%
# check for nulls
stock_df.isna().sum()
# Out:
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
# Get shape
stock_df.shape
# Out:
# (656, 6)

# %%
# Visualize closing price history
plt.figure(figsize=(16,8))
plt.title (f"Closing Price History for '{stock}' - {ticker}")
plt.plot(stock_df['Close'])
plt.xlabel('Date')
plt.ylabel('Close Price USD', fontsize=16)
plt.show()

# %%
stock_df['Close'].plot.density()
plt.xlabel('Distribution of the closing stock price')
plt.show()

# %%
# DF with only close
TSdata_df = stock_df.filter(['Close'])
TSdata_arr = TSdata_df.values # this creates an array of Close Price
TSdata_arr
# Out:
# array([[49.79999924],
#        [48.97999954],
#        [48.59999847],
#        [49.15000153],
#        [48.84999847],
#        [50.09999847],
#        [50.84999847],
#        [51.63000107],
#        [53.5       ],
#        [56.25      ],
#        [56.88000107],
#        [59.70999908],
#        [57.24000168],
#        [57.15000153],
#        [56.27000046],
#        [55.70999908],
#        [54.88999939],
#        [58.29999924],
#        [57.77999878],
#        [58.5       ],
#        [58.31999969],
#        [57.77000046],
#        [57.88999939],
#        [57.63999939],
#        [55.97999954],
#        [55.33000183],
#        [55.25      ],
#        [55.5       ],
#        [56.72999954],
#        [56.13000107],
#        [52.70000076],
#        [53.29999924],
#        [53.45999908],
#        [52.95000076],
#        [52.47999954],
#        [52.93000031],
#        [53.06999969],
#        [50.95000076],
#        [52.47999954],
#        [52.95000076],
#        [52.97999954],
#        [50.79999924],
#        [50.08000183],
#        [50.63000107],
#        [50.20999908],
#        [48.70999908],
#        [49.20000076],
#        [48.56000137],
#        [48.70999908],
#        [48.47000122],
#        [46.75999832],
#        [47.95999908],
#        [49.93000031],
#        [50.34000015],
#        [51.06000137],
#        [51.29999924],
#        [51.61999893],
#        [52.04000092],
#        [52.49000168],
#        [52.88000107],
#        [51.15000153],
#        [49.34999847],
#        [49.61000061],
#        [48.5       ],
#        [48.93000031],
#        [48.36000061],
#        [49.58000183],
#        [49.68999863],
#        [50.45000076],
#        [50.90999985],
#        [49.31000137],
#        [50.15999985],
#        [49.40000153],
#        [49.33000183],
#        [49.31000137],
#        [48.52000046],
#        [47.86999893],
#        [47.54999924],
#        [47.77999878],
#        [49.70999908],
#        [50.93000031],
#        [52.31999969],
#        [51.59999847],
#        [51.75      ],
#        [51.52000046],
#        [50.88000107],
#        [52.61999893],
#        [52.79000092],
#        [50.77000046],
#        [49.11000061],
#        [48.04999924],
#        [48.40000153],
#        [48.43999863],
#        [46.84999847],
#        [45.59999847],
#        [44.77000046],
#        [44.43000031],
#        [44.88999939],
#        [46.79000092],
#        [46.63999939],
#        [45.68999863],
#        [46.84999847],
#        [44.08000183],
#        [43.38000107],
#        [44.50999832],
#        [45.59999847],
#        [43.15999985],
#        [43.27999878],
#        [42.04999924],
#        [40.70999908],
#        [40.81999969],
#        [41.16999817],
#        [42.52000046],
#        [42.36999893],
#        [42.63000107],
#        [41.79999924],
#        [42.54000092],
#        [43.36000061],
#        [43.24000168],
#        [44.45000076],
#        [46.31999969],
#        [46.88000107],
#        [46.97000122],
#        [48.20000076],
#        [49.00999832],
#        [48.        ],
#        [47.50999832],
#        [47.63999939],
#        [48.20999908],
#        [47.90999985],
#        [46.59999847],
#        [47.68000031],
#        [47.22999954],
#        [47.06999969],
#        [47.65000153],
#        [45.97000122],
#        [44.93000031],
#        [45.31000137],
#        [45.34000015],
#        [45.16999817],
#        [43.84999847],
#        [44.00999832],
#        [44.91999817],
#        [47.13000107],
#        [46.81999969],
#        [47.20000076],
#        [47.11999893],
#        [47.81000137],
#        [47.95999908],
#        [47.11999893],
#        [46.81999969],
#        [47.22999954],
#        [49.47000122],
#        [50.47999954],
#        [51.20999908],
#        [51.49000168],
#        [51.02999878],
#        [50.49000168],
#        [52.31000137],
#        [54.16999817],
#        [54.20000076],
#        [54.27999878],
#        [55.79999924],
#        [55.99000168],
#        [55.81000137],
#        [55.15999985],
#        [53.65999985],
#        [53.95000076],
#        [54.86000061],
#        [54.31999969],
#        [53.38999939],
#        [52.66999817],
#        [53.88000107],
#        [54.20000076],
#        [55.20000076],
#        [55.36999893],
#        [54.27999878],
#        [53.36999893],
#        [53.15999985],
#        [51.81999969],
#        [52.27999878],
#        [52.        ],
#        [53.22000122],
#        [53.27000046],
#        [53.13000107],
#        [53.09999847],
#        [54.45000076],
#        [53.27999878],
#        [54.16999817],
#        [54.65999985],
#        [54.25      ],
#        [54.52000046],
#        [54.61000061],
#        [54.93000031],
#        [54.90000153],
#        [55.22000122],
#        [54.83000183],
#        [54.34000015],
#        [54.72999954],
#        [53.75      ],
#        [52.41999817],
#        [52.20999908],
#        [52.18999863],
#        [52.72999954],
#        [52.18999863],
#        [51.5       ],
#        [52.34999847],
#        [52.24000168],
#        [52.27000046],
#        [52.47999954],
#        [53.34000015],
#        [52.59999847],
#        [50.86999893],
#        [50.25      ],
#        [48.49000168],
#        [47.18000031],
#        [47.15999985],
#        [49.66999817],
#        [48.47000122],
#        [46.06999969],
#        [46.74000168],
#        [48.04999924],
#        [49.61000061],
#        [49.20000076],
#        [48.02999878],
#        [48.18999863],
#        [48.79000092],
#        [49.38000107],
#        [48.29999924],
#        [48.63000107],
#        [47.74000168],
#        [47.56000137],
#        [48.75999832],
#        [48.29999924],
#        [46.24000168],
#        [43.95000076],
#        [43.04999924],
#        [39.54999924],
#        [40.40999985],
#        [41.41999817],
#        [40.56000137],
#        [41.90999985],
#        [40.09999847],
#        [38.97000122],
#        [30.53000069],
#        [31.39999962],
#        [27.98999977],
#        [23.67000008],
#        [25.69000053],
#        [22.        ],
#        [26.60000038],
#        [26.44000053],
#        [28.12000084],
#        [27.44000053],
#        [26.57999992],
#        [28.46999931],
#        [30.37999916],
#        [29.68000031],
#        [28.55999947],
#        [28.64999962],
#        [29.23999977],
#        [27.04000092],
#        [28.03000069],
#        [27.96999931],
#        [30.54000092],
#        [32.33000183],
#        [34.79000092],
#        [36.56000137],
#        [35.22999954],
#        [35.36999893],
#        [32.22999954],
#        [31.62999916],
#        [33.41999817],
#        [31.53000069],
#        [30.87999916],
#        [31.84000015],
#        [32.56000137],
#        [33.11999893],
#        [34.43999863],
#        [35.86999893],
#        [37.47000122],
#        [36.68999863],
#        [33.93000031],
#        [33.06000137],
#        [33.36999893],
#        [31.95999908],
#        [32.84999847],
#        [34.33000183],
#        [33.90000153],
#        [33.79000092],
#        [32.34999847],
#        [33.50999832],
#        [33.56000137],
#        [36.74000168],
#        [35.63999939],
#        [36.18000031],
#        [35.81999969],
#        [36.11999893],
#        [38.79000092],
#        [39.81999969],
#        [38.70999908],
#        [38.59999847],
#        [38.61000061],
#        [40.59999847],
#        [41.63000107],
#        [42.70999908],
#        [43.97000122],
#        [45.90000153],
#        [44.40999985],
#        [43.58000183],
#        [39.25999832],
#        [41.22999954],
#        [41.97999954],
#        [42.25      ],
#        [41.16999817],
#        [41.58000183],
#        [41.65000153],
#        [41.74000168],
#        [41.34999847],
#        [38.45000076],
#        [39.97999954],
#        [39.79999924],
#        [40.97999954],
#        [40.75999832],
#        [40.75      ],
#        [41.59000015],
#        [42.45000076],
#        [41.68999863],
#        [40.34999847],
#        [39.43999863],
#        [40.75999832],
#        [41.24000168],
#        [42.43999863],
#        [43.33000183],
#        [43.83000183],
#        [43.66999817],
#        [42.29999924],
#        [43.04000092],
#        [44.34000015],
#        [42.81999969],
#        [42.61000061],
#        [44.        ],
#        [42.61999893],
#        [43.52000046],
#        [41.72999954],
#        [41.06000137],
#        [40.09000015],
#        [41.31999969],
#        [41.99000168],
#        [42.04999924],
#        [42.63000107],
#        [44.79999924],
#        [44.5       ],
#        [44.27999878],
#        [44.43000031],
#        [44.86999893],
#        [44.45999908],
#        [44.70999908],
#        [44.63999939],
#        [43.68999863],
#        [43.59000015],
#        [46.11999893],
#        [45.59000015],
#        [46.34000015],
#        [46.15999985],
#        [46.04999924],
#        [45.11999893],
#        [47.27000046],
#        [49.22000122],
#        [48.38999939],
#        [48.59999847],
#        [47.93000031],
#        [49.22999954],
#        [48.70000076],
#        [49.84999847],
#        [50.09000015],
#        [51.06999969],
#        [49.70000076],
#        [50.97000122],
#        [50.36999893],
#        [47.90999985],
#        [47.79999924],
#        [46.74000168],
#        [46.40999985],
#        [46.04000092],
#        [47.47999954],
#        [46.56999969],
#        [47.04999924],
#        [46.11000061],
#        [47.31000137],
#        [48.58000183],
#        [47.88000107],
#        [48.29999924],
#        [49.38000107],
#        [49.36000061],
#        [48.58000183],
#        [47.88000107],
#        [48.83000183],
#        [49.00999832],
#        [49.29999924],
#        [48.84000015],
#        [49.34000015],
#        [48.54999924],
#        [48.81999969],
#        [48.52999878],
#        [47.15000153],
#        [46.56999969],
#        [45.18000031],
#        [46.25      ],
#        [45.49000168],
#        [47.81999969],
#        [48.72999954],
#        [46.45000076],
#        [48.97000122],
#        [48.22999954],
#        [52.11999893],
#        [53.45999908],
#        [52.20999908],
#        [51.04000092],
#        [51.97000122],
#        [53.93000031],
#        [54.47999954],
#        [55.29999924],
#        [55.34000015],
#        [54.72999954],
#        [55.93999863],
#        [57.72999954],
#        [56.43000031],
#        [55.40000153],
#        [53.00999832],
#        [53.52999878],
#        [53.20000076],
#        [53.59999847],
#        [55.04999924],
#        [53.20999908],
#        [54.54999924],
#        [54.65999985],
#        [54.43000031],
#        [54.        ],
#        [53.06000137],
#        [54.13000107],
#        [53.83000183],
#        [53.83000183],
#        [55.65999985],
#        [55.08000183],
#        [54.66999817],
#        [54.75      ],
#        [54.79000092],
#        [54.29000092],
#        [54.33000183],
#        [55.47000122],
#        [55.5       ],
#        [54.04000092],
#        [55.79999924],
#        [58.43000031],
#        [58.50999832],
#        [58.20999908],
#        [58.86000061],
#        [61.04000092],
#        [60.02999878],
#        [59.65000153],
#        [57.31000137],
#        [57.54999924],
#        [58.56999969],
#        [57.56000137],
#        [57.5       ],
#        [57.22999954],
#        [55.74000168],
#        [54.38999939],
#        [54.38000107],
#        [51.90000153],
#        [52.75      ],
#        [54.61000061],
#        [55.34999847],
#        [56.34000015],
#        [57.24000168],
#        [57.34999847],
#        [56.59999847],
#        [57.66999817],
#        [57.66999817],
#        [58.15000153],
#        [58.75      ],
#        [58.54000092],
#        [57.56000137],
#        [60.38999939],
#        [62.47999954],
#        [62.11999893],
#        [63.68999863],
#        [61.34999847],
#        [59.31000137],
#        [61.54000092],
#        [62.72999954],
#        [62.25      ],
#        [61.20000076],
#        [62.90999985],
#        [63.43999863],
#        [62.25999832],
#        [64.08999634],
#        [64.31999969],
#        [64.33999634],
#        [62.90000153],
#        [63.18000031],
#        [66.01000214],
#        [64.72000122],
#        [63.90999985],
#        [63.50999832],
#        [60.75      ],
#        [62.04000092],
#        [63.24000168],
#        [63.99000168],
#        [63.90000153],
#        [64.61000061],
#        [63.93999863],
#        [64.59999847],
#        [64.58999634],
#        [64.59999847],
#        [63.99000168],
#        [63.18999863],
#        [63.13999939],
#        [63.79000092],
#        [63.31000137],
#        [64.23999786],
#        [64.56999969],
#        [64.68000031],
#        [64.55000305],
#        [62.47999954],
#        [64.81999969],
#        [60.93000031],
#        [62.11000061],
#        [62.20000076],
#        [62.65000153],
#        [63.31000137],
#        [64.05999756],
#        [62.5       ],
#        [64.55000305],
#        [66.22000122],
#        [68.06999969],
#        [69.04000092],
#        [69.04000092],
#        [68.73000336],
#        [68.56999969],
#        [67.59999847],
#        [68.08000183],
#        [69.83000183],
#        [70.91000366],
#        [69.52999878],
#        [68.55000305],
#        [68.26000214],
#        [68.83000183],
#        [69.55000305],
#        [69.04000092],
#        [69.56999969],
#        [68.66000366],
#        [68.41999817],
#        [70.41000366],
#        [68.94999695],
#        [70.61000061],
#        [70.37000275],
#        [69.23999786],
#        [69.37999725],
#        [68.83999634],
#        [67.98999786],
#        [68.        ],
#        [66.95999908],
#        [67.22000122],
#        [65.58999634],
#        [63.54000092],
#        [61.97999954],
#        [63.11000061],
#        [63.5       ],
#        [63.15000153],
#        [63.11000061],
#        [63.29000092],
#        [62.90000153],
#        [62.97999954],
#        [63.27999878],
#        [63.5       ],
#        [63.50999832],
#        [61.93000031],
#        [62.25      ],
#        [61.40999985],
#        [63.08000183],
#        [63.22000122],
#        [62.70000076],
#        [62.31999969],
#        [61.90999985],
#        [60.00999832],
#        [57.79000092],
#        [58.61999893],
#        [59.72999954],
#        [60.47999954],
#        [60.11000061],
#        [62.00999832],
#        [61.95000076],
#        [61.86999893],
#        [62.59999847],
#        [62.15999985],
#        [61.22000122],
#        [62.22999954],
#        [60.99000168],
#        [61.        ],
#        [62.        ],
#        [61.81999969],
#        [63.11999893],
#        [64.23999786],
#        [64.01000214],
#        [63.68999863],
#        [63.31999969],
#        [62.31000137],
#        [61.88000107],
#        [60.54999924],
#        [60.88999939],
#        [62.06000137],
#        [63.25999832],
#        [63.86999893],
#        [63.65000153],
#        [65.37999725],
#        [63.97999954],
#        [62.90000153],
#        [62.54000092],
#        [62.61999893],
#        [62.11999893],
#        [61.86999893],
#        [60.68999863],
#        [60.27999878],
#        [60.40999985],
#        [60.72000122],
#        [59.65000153],
#        [60.20000076],
#        [59.47000122],
#        [57.75      ],
#        [56.18000031],
#        [55.52999878],
#        [56.29999924],
#        [57.43000031],
#        [56.81000137],
#        [59.68999863],
#        [59.45999908],
#        [58.81999969],
#        [57.56000137],
#        [58.58000183],
#        [58.24000168],
#        [59.09999847],
#        [57.15999985],
#        [58.50999832],
#        [58.70999908],
#        [58.22999954],
#        [57.74000168],
#        [56.90999985],
#        [58.74000168],
#        [58.95999908],
#        [58.95000076],
#        [59.18999863],
#        [59.88999939],
#        [59.25999832],
#        [58.40000153]])

# %%
# Scale the Data
scaler = MinMaxScaler(feature_range =(0,1))
scaled_data = scaler.fit_transform(TSdata_arr)
# scaled_data

# %%
training_data_len = math.ceil(len(TSdata_arr) * 0.75)
training_data_len
# Out:
# 492

# %%
# Created scaled training dataset
train_data = scaled_data[0:training_data_len]
train_data.shape
# Out:
# (492, 1)

# %%
# Split
X_train = []
y_train = []

for i in range(ts_points, len(train_data)):
    X_train.append(train_data[i-ts_points:i,0])
    y_train.append(train_data[i,0])
    # if i <= ts_points+3:
    #     print(X_train)
    #     print(y_train)
    #     print()

# %%
# convert X_train and y_train to numpy arrays for LSTM
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
print (X_train.shape)
print (y_train.shape)
# Out:
# (372, 120)
# (372,)

# %%
# LSTM network expects a 3D input (No_of_Samples, number of time steps, and number of features) no_of_features = 1 (Close)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_train.shape
# Out:
# (372, 120, 1)

# %%
training_data_len - ts_points
# Out:
# 372

# %%
# hidden_nodes = int(2/3 * (X_train.shape[1] * 1))
# print(f"The number of hidden nodes is {hidden_nodes}.")

# %%
# LSTM MOdel
model = tf.keras.models.Sequential()
# model.add(tf.keras.layers.LSTM(50, return_sequences=True, input_shape=(X_train.shape[1],1)))
# model.add(tf.keras.layers.LSTM(50, return_sequences=False))
# model.add(tf.keras.layers.Dropout(0.2))
# model.add(tf.keras.layers.Dense(25))
# model.add(tf.keras.layers.Dense(1))
# model.summary()

# %%
# BEST FOR TESLA#
model.add(tf.keras.layers.LSTM(50, return_sequences=True, input_shape=(X_train.shape[1],1)))
model.add(tf.keras.layers.LSTM(50, return_sequences=False))
# model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(25))
model.add(tf.keras.layers.Dense(1))
model.summary()

#model.fit(X_train, y_train, batch_size=64, epochs=50
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 120, 50)           10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 25)                1275
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 31,901
# Trainable params: 31,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
# model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
import os
from tensorflow.keras.callbacks import ModelCheckpoint

batch_size=64

os.makedirs("chk_points/", exist_ok=True)
chkpoint_path="chk_points/weights.{epoch}.hdf5"

# Create chk points
chkpt_callback = ModelCheckpoint(filepath=chkpoint_path,
                              verbose=1,
                              save_weights_only=True,
                              save_freq="epoch",
                              period=5)

# chkpoint_path = "chk_points/cp-{epoch:04d}.ckpt"
# chkpt_callback = tf.keras.callbacks.ModelCheckpoint(
#     filepath=chkpoint_path, 
#     verbose=1, 
#     save_weights_only=True,
#     save_freq=5*batch_size)                    

# model.save_weights(chkpoint_path.format(epoch=0))
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# training_data_len
# scaled_data

# %%
# model.fit(X_train, y_train, batch_size=batch_size, epochs=50, validation_split=0.43, callbacks=[chkpt_callback])
model.fit(X_train, y_train, batch_size=64, epochs=100)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 1s 99ms/step - loss: 0.0022
# Epoch 2/100
# 6/6 [==============================] - 1s 82ms/step - loss: 0.0022
# Epoch 3/100
# 6/6 [==============================] - 1s 83ms/step - loss: 0.0022: 0s - loss: 0.0
# Epoch 4/100
# 6/6 [==============================] - 1s 91ms/step - loss: 0.0023
# Epoch 5/100
# 6/6 [==============================] - 1s 91ms/step - loss: 0.0020
# Epoch 6/100
# 6/6 [==============================] - 0s 82ms/step - loss: 0.0020
# Epoch 7/100
# 6/6 [==============================] - 0s 82ms/step - loss: 0.0020
# Epoch 8/100
# 6/6 [==============================] - 0s 81ms/step - loss: 0.0019
# Epoch 9/100
# 6/6 [==============================] - 0s 82ms/step - loss: 0.0019
# Epoch 10/100
# 6/6 [==============================] - 0s 82ms/step - loss: 0.0020
# Epoch 11/100
# 6/6 [==============================] - 0s 81ms/step - loss: 0.0019
# Epoch 12/100
# 6/6 [==============================] - 1s 88ms/step - loss: 0.0019
# Epoch 13/100
# 6/6 [==============================] - 1s 83ms/step - loss: 0.0019
# Epoch 14/100
# 6/6 [==============================] - 0s 81ms/step - loss: 0.0018
# Epoch 15/100
# 6/6 [==============================] - 0s 81ms/step - loss: 0.0018
# Epoch 16/100
# 6/6 [==============================] - 0s 82ms/step - loss: 0.0019
# Epoch 17/100
# 6/6 [==============================] - 0s 82ms/step - loss: 0.0017
# Epoch 18/100
# 6/6 [==============================] - 0s 82ms/step - loss: 0.0018
# Epoch 19/100
# 6/6 [==============================] - 0s 82ms/step - loss: 0.0018
# Epoch 20/100
# 6/6 [==============================] - 0s 82ms/step - loss: 0.0018
# Epoch 21/100
# 6/6 [==============================] - 1s 85ms/step - loss: 0.0017
# Epoch 22/100
# 6/6 [==============================] - 1s 83ms/step - loss: 0.0017
# Epoch 23/100
# 6/6 [==============================] - 1s 86ms/step - loss: 0.0016
# Epoch 24/100
# 6/6 [==============================] - 0s 82ms/step - loss: 0.0016
# Epoch 25/100
# 6/6 [==============================] - 0s 82ms/step - loss: 0.0017
# Epoch 26/100
# 6/6 [==============================] - 0s 82ms/step - loss: 0.0016
# Epoch 27/100
# 6/6 [==============================] - 1s 87ms/step - loss: 0.0016
# Epoch 28/100
# 6/6 [==============================] - 1s 86ms/step - loss: 0.0016
# Epoch 29/100
# 6/6 [==============================] - 1s 83ms/step - loss: 0.0016
# Epoch 30/100
# 6/6 [==============================] - 1s 83ms/step - loss: 0.0016
# Epoch 31/100
# 6/6 [==============================] - 1s 85ms/step - loss: 0.0015
# Epoch 32/100
# 6/6 [==============================] - 1s 88ms/step - loss: 0.0016
# Epoch 33/100
# 6/6 [==============================] - 1s 84ms/step - loss: 0.0016
# Epoch 34/100
# 6/6 [==============================] - 1s 91ms/step - loss: 0.0016
# Epoch 35/100
# 6/6 [==============================] - 1s 92ms/step - loss: 0.0015
# Epoch 36/100
# 6/6 [==============================] - 1s 95ms/step - loss: 0.0015
# Epoch 37/100
# 6/6 [==============================] - 1s 86ms/step - loss: 0.0015
# Epoch 38/100
# 6/6 [==============================] - 1s 85ms/step - loss: 0.0017
# Epoch 39/100
# 6/6 [==============================] - 1s 84ms/step - loss: 0.0018
# Epoch 40/100
# 6/6 [==============================] - 1s 85ms/step - loss: 0.0018
# Epoch 41/100
# 6/6 [==============================] - 1s 85ms/step - loss: 0.0015
# Epoch 42/100
# 6/6 [==============================] - 1s 84ms/step - loss: 0.0015
# Epoch 43/100
# 6/6 [==============================] - 1s 86ms/step - loss: 0.0015
# Epoch 44/100
# 6/6 [==============================] - 1s 89ms/step - loss: 0.0015
# Epoch 45/100
# 6/6 [==============================] - 1s 84ms/step - loss: 0.0015
# Epoch 46/100
# 6/6 [==============================] - 1s 84ms/step - loss: 0.0014
# Epoch 47/100
# 6/6 [==============================] - 1s 85ms/step - loss: 0.0015
# Epoch 48/100
# 6/6 [==============================] - 1s 89ms/step - loss: 0.0016
# Epoch 49/100
# 6/6 [==============================] - 1s 84ms/step - loss: 0.0014
# Epoch 50/100
# 6/6 [==============================] - 1s 86ms/step - loss: 0.0013: 0s - loss: 0.
# Epoch 51/100
# 6/6 [==============================] - 1s 85ms/step - loss: 0.0013
# Epoch 52/100
# 6/6 [==============================] - 1s 85ms/step - loss: 0.0013
# Epoch 53/100
# 6/6 [==============================] - 1s 85ms/step - loss: 0.0013
# Epoch 54/100
# 6/6 [==============================] - 1s 84ms/step - loss: 0.0015
# Epoch 55/100
# 6/6 [==============================] - 1s 90ms/step - loss: 0.0015
# Epoch 56/100
# 6/6 [==============================] - 1s 87ms/step - loss: 0.0015
# Epoch 57/100
# 6/6 [==============================] - 1s 84ms/step - loss: 0.0014
# Epoch 58/100
# 6/6 [==============================] - 1s 88ms/step - loss: 0.0013
# Epoch 59/100
# 6/6 [==============================] - 1s 86ms/step - loss: 0.0013
# Epoch 60/100
# 6/6 [==============================] - 1s 84ms/step - loss: 0.0013
# Epoch 61/100
# 6/6 [==============================] - 1s 83ms/step - loss: 0.0013
# Epoch 62/100
# 6/6 [==============================] - 1s 84ms/step - loss: 0.0013
# Epoch 63/100
# 6/6 [==============================] - 1s 88ms/step - loss: 0.0013
# Epoch 64/100
# 6/6 [==============================] - 1s 92ms/step - loss: 0.0014
# Epoch 65/100
# 6/6 [==============================] - 1s 101ms/step - loss: 0.0015
# Epoch 66/100
# 6/6 [==============================] - 1s 104ms/step - loss: 0.0014
# Epoch 67/100
# 6/6 [==============================] - 1s 103ms/step - loss: 0.0013
# Epoch 68/100
# 6/6 [==============================] - 1s 92ms/step - loss: 0.0012
# Epoch 69/100
# 6/6 [==============================] - 1s 93ms/step - loss: 0.0013
# Epoch 70/100
# 6/6 [==============================] - 1s 93ms/step - loss: 0.0013
# Epoch 71/100
# 6/6 [==============================] - 1s 92ms/step - loss: 0.0014
# Epoch 72/100
# 6/6 [==============================] - 1s 92ms/step - loss: 0.0013
# Epoch 73/100
# 6/6 [==============================] - 1s 92ms/step - loss: 0.0012
# Epoch 74/100
# 6/6 [==============================] - 1s 100ms/step - loss: 0.0011
# Epoch 75/100
# 6/6 [==============================] - 1s 93ms/step - loss: 0.0011
# Epoch 76/100
# 6/6 [==============================] - 1s 94ms/step - loss: 0.0011
# Epoch 77/100
# 6/6 [==============================] - 1s 94ms/step - loss: 0.0011
# Epoch 78/100
# 6/6 [==============================] - 1s 92ms/step - loss: 0.0012
# Epoch 79/100
# 6/6 [==============================] - 1s 93ms/step - loss: 0.0011
# Epoch 80/100
# 6/6 [==============================] - 1s 92ms/step - loss: 0.0012
# Epoch 81/100
# 6/6 [==============================] - 1s 92ms/step - loss: 0.0011
# Epoch 82/100
# 6/6 [==============================] - 1s 93ms/step - loss: 0.0011
# Epoch 83/100
# 6/6 [==============================] - 1s 92ms/step - loss: 0.0010
# Epoch 84/100
# 6/6 [==============================] - 1s 98ms/step - loss: 0.0011
# Epoch 85/100
# 6/6 [==============================] - 1s 95ms/step - loss: 0.0011
# Epoch 86/100
# 6/6 [==============================] - 1s 93ms/step - loss: 0.0012
# Epoch 87/100
# 6/6 [==============================] - 1s 93ms/step - loss: 0.0014
# Epoch 88/100
# 6/6 [==============================] - 1s 92ms/step - loss: 0.0011
# Epoch 89/100
# 6/6 [==============================] - 1s 95ms/step - loss: 0.0011
# Epoch 90/100
# 6/6 [==============================] - 1s 95ms/step - loss: 0.0012
# Epoch 91/100
# 6/6 [==============================] - 1s 98ms/step - loss: 0.0011
# Epoch 92/100
# 6/6 [==============================] - 1s 101ms/step - loss: 0.0011
# Epoch 93/100
# 6/6 [==============================] - 1s 101ms/step - loss: 0.0011
# Epoch 94/100
# 6/6 [==============================] - 1s 109ms/step - loss: 0.0013
# Epoch 95/100
# 6/6 [==============================] - 1s 103ms/step - loss: 0.0012
# Epoch 96/100
# 6/6 [==============================] - 1s 94ms/step - loss: 0.0010
# Epoch 97/100
# 6/6 [==============================] - 1s 91ms/step - loss: 9.8333e-04
# Epoch 98/100
# 6/6 [==============================] - 1s 92ms/step - loss: 9.7189e-04
# Epoch 99/100
# 6/6 [==============================] - 1s 92ms/step - loss: 0.0010
# Epoch 100/100
# 6/6 [==============================] - 1s 92ms/step - loss: 0.0011

# %%
model.save('Saved_Models/Model_'+ticker+'.h5')

# %%
# test_data = scaled_data[training_data_len:]

# Bring in the last 'ts_points' (60 values) from training set so when X_test is used to predict , predictions have same shape as Y_test
# The for loop starts with 'ts_points' thatbmeans the resultant array will have 60 less rows
test_data = scaled_data[training_data_len-ts_points:]
# test_data[0:60,0]

# %%
X_test = []
y_test = TSdata_arr[training_data_len:]
for i in range(ts_points, len(test_data)):
    X_test.append(test_data[i-ts_points:i,0])

# %%
# convert the data to a numpy array to use it in LSTM MODEL
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],  X_test.shape[1], 1))

# %%
from sklearn.metrics import mean_squared_error

# %%
# Models predicted price for X_train
predictions_tr = model.predict(X_train)
predictions_tr = scaler.inverse_transform(predictions_tr)

y_train_tr =  scaler.inverse_transform(y_train.reshape(-1,1))
rmse_tr = math.sqrt(mean_squared_error(y_train_tr, predictions_tr))
rmse_tr
# Out:
# 1.4941231741208838

# %%
# Models predicted price for X_test
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)

# %%
y_test.shape, predictions.shape
# Out:
# ((164, 1), (164, 1))

# %%
# RMSE to check accuracy

rmse = math.sqrt(mean_squared_error(y_test, predictions))
rmse
# Out:
# 1.3725315421277084

# %%
# Plot
train = TSdata_df[:training_data_len]
actual = TSdata_df[training_data_len:]
actual['Predictions'] = predictions
actual
# Out:
# <ipython-input-34-bb86776ae978>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   actual['Predictions'] = predictions
#                 Close  Predictions
# Date
# 2021-03-03  62.250000    62.320747
# 2021-03-04  61.200001    62.544651
# 2021-03-05  62.910000    61.858742
# 2021-03-08  63.439999    62.732220
# 2021-03-09  62.259998    63.548172
# ...               ...          ...
# 2021-10-18  58.950001    58.798199
# 2021-10-19  59.189999    59.010685
# 2021-10-20  59.889999    59.214149
# 2021-10-21  59.259998    59.752613
# 2021-10-22  58.400002    59.541332
#
# [164 rows x 2 columns]

# %%
plt.figure(figsize=(16,8))
plt.title(f"Model for '{stock}' - {ticker}")
plt.xlabel("Date")
plt.ylabel("Close Price USD")
plt.plot(train['Close'])
plt.plot(actual[['Close', 'Predictions']])
plt.legend(['Train', 'Actual', 'Predictions'], loc='lower right')
plt.show()

# %% [markdown]
# # TEST

# %%
# for predictions add 100 extra days to make sure it has more than ts_points to make up for missing days (weekends and holidays)

fetch_days = ts_points + 100    

sd =  today - timedelta(days=fetch_days)
sd = sd.strftime('%Y-%m-%d')

ed = today.strftime('%Y-%m-%d')
ed

next_day = (today + timedelta(days=1) ).strftime('%Y-%m-%d')
# next_day

# %%
# get the quote
quote = pdr.DataReader(ticker, data_source="yahoo", start=sd, end=ed)
new_df = quote.filter(['Close'])
last_n_days = ts_points
last_n_days_arr = new_df[-last_n_days:].values

# %%
last_n_days_scaled = scaler.transform(last_n_days_arr)
X_test = []
X_test.append(last_n_days_scaled)
X_test = np.array(X_test)
X_test = np.reshape(X_test,(X_test.shape[0], X_test.shape[1],1))

# %%
##########################loading saved model ###############################
new_model = tf.keras.models.load_model('Saved_Models/Model_'+ticker+'.h5')

# Check its architecture
new_model.summary()
nmpred_price = new_model.predict(X_test)
nmpred_price = scaler.inverse_transform(nmpred_price)
nmpred_price = nmpred_price[0][0]
print(f"Predicted Closing price for '{stock}' on {next_day} is {nmpred_price:.4f}")
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 120, 50)           10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 25)                1275
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 31,901
# Trainable params: 31,901
# Non-trainable params: 0
# _________________________________________________________________
# Predicted Closing price for 'DOW' on 2021-10-23 is 58.8143

# %%
pred_price = model.predict(X_test)
pred_price = scaler.inverse_transform(pred_price)
pred_price = pred_price[0][0]
print(f"Predicted Closing price for '{stock}' on {next_day} is {pred_price:.4f}")
# Out:
# Predicted Closing price for 'DOW' on 2021-10-23 is 58.8143

# %%
# verify
d1 = today - timedelta(days=5)
d1 = d1.strftime('%Y-%m-%d')

quote2 = pdr.DataReader(ticker, data_source="yahoo", start=d1)
quote2
# Out:
#                  High        Low       Open      Close   Volume  Adj Close
# Date
# 2021-10-18  59.389999  57.599998  57.700001  58.950001  4660100  58.950001
# 2021-10-19  59.270000  58.540001  59.090000  59.189999  3650600  59.189999
# 2021-10-20  60.608002  58.941002  59.160000  59.889999  5875300  59.889999
# 2021-10-21  61.169998  57.959999  60.070000  59.259998  8916600  59.259998
# 2021-10-22  60.189999  58.380001  59.639999  58.400002  5889477  58.400002
