# %%
import math
import numpy as np
import os
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas_datareader as pdr
from datetime import datetime, timedelta

# %%
#Get the stock
ticker = 'BKNG'
stock ="Booking Holdings Inc"
# Time step n days, here we will use n  days historical data to predict next day closing
ts_points = 120
# train_data[0:60,0]  

today = datetime.today()
# start_date ='2016-01-01'
start_date = (today - timedelta(days=5*365) ).strftime('%Y-%m-%d')

# end_date   = today.strftime('%Y-%m-%d')
end_date = (today - timedelta(days=31) ).strftime('%Y-%m-%d')

stock_df = pdr.DataReader(ticker, data_source="yahoo", start=start_date, end=end_date)

# %%
# Date is an index but to be sure , let's sort
stock_df = stock_df.sort_index(ascending=True)
stock_df
# Out:
#                    High          Low         Open        Close  Volume  \
# Date
# 2016-10-26  1477.550049  1465.479980  1475.000000  1469.160034  416700
# 2016-10-27  1480.000000  1461.079956  1475.099976  1463.020020  358800
# 2016-10-28  1483.000000  1460.000000  1465.079956  1474.819946  600900
# 2016-10-31  1479.609985  1472.280029  1478.300049  1474.229980  284200
# 2016-11-01  1480.010010  1453.930054  1474.229980  1467.000000  562900
# ...                 ...          ...          ...          ...     ...
# 2021-09-20  2345.790039  2285.899902  2310.000000  2340.739990  311800
# 2021-09-21  2363.520020  2322.389893  2363.520020  2325.620117  211100
# 2021-09-22  2427.290039  2338.850098  2338.850098  2406.110107  417000
# 2021-09-23  2488.929932  2410.649902  2410.649902  2475.510010  419500
# 2021-09-24  2502.489990  2452.379883  2452.379883  2491.350098  298900
#
#               Adj Close
# Date
# 2016-10-26  1469.160034
# 2016-10-27  1463.020020
# 2016-10-28  1474.819946
# 2016-10-31  1474.229980
# 2016-11-01  1467.000000
# ...                 ...
# 2021-09-20  2340.739990
# 2021-09-21  2325.620117
# 2021-09-22  2406.110107
# 2021-09-23  2475.510010
# 2021-09-24  2491.350098
#
# [1237 rows x 6 columns]

# %%
# check for nulls
stock_df.isna().sum()
# Out:
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
# Get shape
stock_df.shape
# Out:
# (1237, 6)

# %%
# Visualize closing price history
plt.figure(figsize=(16,8))
plt.title (f"Closing Price History for '{stock}' - {ticker}")
plt.plot(stock_df['Close'])
plt.xlabel('Date')
plt.ylabel('Close Price USD', fontsize=16)
plt.savefig('Saved_Models/Images/his_'+ticker+'.png')
plt.show()

# %%
stock_df['Close'].plot.density()
plt.xlabel('Distribution of the closing stock price')
plt.savefig('Saved_Models/Images/den_'+ticker+'.png')
plt.show()

# %%
# DF with only close
TSdata_df = stock_df.filter(['Close'])
TSdata_df
# Out:
#                   Close
# Date
# 2016-10-26  1469.160034
# 2016-10-27  1463.020020
# 2016-10-28  1474.819946
# 2016-10-31  1474.229980
# 2016-11-01  1467.000000
# ...                 ...
# 2021-09-20  2340.739990
# 2021-09-21  2325.620117
# 2021-09-22  2406.110107
# 2021-09-23  2475.510010
# 2021-09-24  2491.350098
#
# [1237 rows x 1 columns]

# %%
TSdata_arr = TSdata_df.values # this creates an array of Close Price
TSdata_arr
# Out:
# array([[1469.16003418],
#        [1463.02001953],
#        [1474.81994629],
#        ...,
#        [2406.11010742],
#        [2475.51000977],
#        [2491.35009766]])

# %%
from statsmodels.tsa.stattools import adfuller
import pandas as pd
import numpy as np

# ADF Test
result = adfuller(TSdata_arr, autolag='AIC')

print('ADF Statistic: %f' % result[0])

print('p-value: %f' % result[1])

print('Critical Values:')

for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
if result[0] < result[4]["5%"]:
    print ("Reject Ho - Time Series is Stationary")
else:
    print ("Failed to Reject Ho - Time Series is Non-Stationary")
# Out:
# ADF Statistic: -2.450240
# p-value: 0.128055
# Critical Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568
# Failed to Reject Ho - Time Series is Non-Stationary

# %%
df2 = TSdata_df['Close'].diff().dropna().to_frame()
df2
# Out:
#                 Close
# Date
# 2016-10-27  -6.140015
# 2016-10-28  11.799927
# 2016-10-31  -0.589966
# 2016-11-01  -7.229980
# 2016-11-02 -21.670044
# ...               ...
# 2021-09-20  15.369873
# 2021-09-21 -15.119873
# 2021-09-22  80.489990
# 2021-09-23  69.399902
# 2021-09-24  15.840088
#
# [1236 rows x 1 columns]

# %%
# Visualize closing price history
plt.figure(figsize=(16,8))
plt.title (f"Closing Price History for '{stock}' - {ticker}")
plt.plot(df2['Close'])
plt.xlabel('Date')
plt.ylabel('Close Price USD', fontsize=16)
plt.savefig('Saved_Models/Images/diff_'+ticker+'.png')
plt.show()

# %%
# TSdata_arr = df2.filter(['Close']).values
# TSdata_arr

# %%
# Scale the Data
scaler = MinMaxScaler(feature_range =(0,1))
scaled_data = scaler.fit_transform(TSdata_arr)
# scaled_data

# %%
training_data_len = math.ceil(len(TSdata_arr) * 0.75)
training_data_len
# Out:
# 928

# %%
# Created scaled training dataset
train_data = scaled_data[0:training_data_len]
train_data.shape
# Out:
# (928, 1)

# %%
# Split
X_train = []
y_train = []

for i in range(ts_points, len(train_data)):
    X_train.append(train_data[i-ts_points:i,0])
    y_train.append(train_data[i,0])
    # if i <= ts_points+3:
    #     print(X_train)
    #     print(y_train)
    #     print()

# %%
# convert X_train and y_train to numpy arrays for LSTM
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
print (X_train.shape)
print (y_train.shape)
# Out:
# (808, 120)
# (808,)

# %%
# LSTM network expects a 3D input (No_of_Samples, number of time steps, and number of features) no_of_features = 1 (Close)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_train.shape
# Out:
# (808, 120, 1)

# %%
training_data_len - ts_points
# Out:
# 808

# %%
# hidden_nodes = int(2/3 * (X_train.shape[1] * 1))
# print(f"The number of hidden nodes is {hidden_nodes}.")

# %%
# LSTM MOdel
model = tf.keras.models.Sequential()
# model.add(tf.keras.layers.LSTM(50, return_sequences=True, input_shape=(X_train.shape[1],1)))
# model.add(tf.keras.layers.LSTM(50, return_sequences=False))
# model.add(tf.keras.layers.Dropout(0.2))
# model.add(tf.keras.layers.Dense(25))
# model.add(tf.keras.layers.Dense(1))
# model.summary()

# %%
# # BEST FOR BKNG#
model.add(tf.keras.layers.LSTM(50, return_sequences=True, input_shape=(X_train.shape[1],1)))
model.add(tf.keras.layers.LSTM(50, return_sequences=False))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(25))
model.add(tf.keras.layers.Dense(1))
model.summary()

# #model.fit(X_train, y_train, batch_size=64, epochs=50
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 120, 50)           10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dropout (Dropout)            (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 25)                1275
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 31,901
# Trainable params: 31,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
# model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
import os
from tensorflow.keras.callbacks import ModelCheckpoint

batch_size=64

os.makedirs("chk_points/", exist_ok=True)
chkpoint_path="chk_points/weights.{epoch}.hdf5"

# Create chk points
chkpt_callback = ModelCheckpoint(filepath=chkpoint_path,
                              verbose=1,
                              save_weights_only=True,
                              save_freq="epoch",
                              period=5)

# chkpoint_path = "chk_points/cp-{epoch:04d}.ckpt"
# chkpt_callback = tf.keras.callbacks.ModelCheckpoint(
#     filepath=chkpoint_path, 
#     verbose=1, 
#     save_weights_only=True,
#     save_freq=5*batch_size)                    

# model.save_weights(chkpoint_path.format(epoch=0))
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# training_data_len
# scaled_data

# %%
# model.fit(X_train, y_train, batch_size=batch_size, epochs=50, validation_split=0.43, callbacks=[chkpt_callback])
model.fit(X_train, y_train, batch_size=64 ,epochs=32)
# Out:
# Epoch 1/32
# 13/13 [==============================] - 4s 88ms/step - loss: 0.0869
# Epoch 2/32
# 13/13 [==============================] - 1s 103ms/step - loss: 0.0119
# Epoch 3/32
# 13/13 [==============================] - 1s 95ms/step - loss: 0.0076
# Epoch 4/32
# 13/13 [==============================] - 1s 95ms/step - loss: 0.0067
# Epoch 5/32
# 13/13 [==============================] - 1s 91ms/step - loss: 0.0064
# Epoch 6/32
# 13/13 [==============================] - 1s 101ms/step - loss: 0.0055
# Epoch 7/32
# 13/13 [==============================] - 1s 86ms/step - loss: 0.0053
# Epoch 8/32
# 13/13 [==============================] - 1s 86ms/step - loss: 0.0048
# Epoch 9/32
# 13/13 [==============================] - 1s 87ms/step - loss: 0.0049
# Epoch 10/32
# 13/13 [==============================] - 1s 86ms/step - loss: 0.0045
# Epoch 11/32
# 13/13 [==============================] - 1s 90ms/step - loss: 0.0042
# Epoch 12/32
# 13/13 [==============================] - 1s 86ms/step - loss: 0.0045
# Epoch 13/32
# 13/13 [==============================] - 1s 86ms/step - loss: 0.0039
# Epoch 14/32
# 13/13 [==============================] - 1s 92ms/step - loss: 0.0041
# Epoch 15/32
# 13/13 [==============================] - 1s 91ms/step - loss: 0.0038
# Epoch 16/32
# 13/13 [==============================] - 1s 91ms/step - loss: 0.0040
# Epoch 17/32
# 13/13 [==============================] - 1s 96ms/step - loss: 0.0038
# Epoch 18/32
# 13/13 [==============================] - 1s 98ms/step - loss: 0.0037
# Epoch 19/32
# 13/13 [==============================] - 1s 96ms/step - loss: 0.0033
# Epoch 20/32
# 13/13 [==============================] - 1s 91ms/step - loss: 0.0035
# Epoch 21/32
# 13/13 [==============================] - 1s 90ms/step - loss: 0.0035
# Epoch 22/32
# 13/13 [==============================] - 1s 91ms/step - loss: 0.0033
# Epoch 23/32
# 13/13 [==============================] - 1s 92ms/step - loss: 0.0035
# Epoch 24/32
# 13/13 [==============================] - 1s 93ms/step - loss: 0.0032
# Epoch 25/32
# 13/13 [==============================] - 1s 90ms/step - loss: 0.0033
# Epoch 26/32
# 13/13 [==============================] - 1s 92ms/step - loss: 0.0034
# Epoch 27/32
# 13/13 [==============================] - 1s 92ms/step - loss: 0.0031
# Epoch 28/32
# 13/13 [==============================] - 1s 97ms/step - loss: 0.0029
# Epoch 29/32
# 13/13 [==============================] - 1s 91ms/step - loss: 0.0030
# Epoch 30/32
# 13/13 [==============================] - 1s 91ms/step - loss: 0.0029
# Epoch 31/32
# 13/13 [==============================] - 1s 94ms/step - loss: 0.0029
# Epoch 32/32
# 13/13 [==============================] - 1s 90ms/step - loss: 0.0031

# %%
model.save('Saved_Models/Model_'+ticker+'.h5')

# %%
# test_data = scaled_data[training_data_len:]

# Bring in the last 'ts_points' (60 values) from training set so when X_test is used to predict , predictions have same shape as Y_test
# The for loop starts with 'ts_points' thatbmeans the resultant array will have 60 less rows
test_data = scaled_data[training_data_len-ts_points:]
# test_data[0:60,0]

# %%
X_test = []
y_test = TSdata_arr[training_data_len:]
for i in range(ts_points, len(test_data)):
    X_test.append(test_data[i-ts_points:i,0])

# %%
# convert the data to a numpy array to use it in LSTM MODEL
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],  X_test.shape[1], 1))

# %%
from sklearn.metrics import mean_squared_error

# %%
# Models predicted price for X_train
predictions_tr = model.predict(X_train)
predictions_tr = scaler.inverse_transform(predictions_tr)

y_train_tr =  scaler.inverse_transform(y_train.reshape(-1,1))
rmse_tr = math.sqrt(mean_squared_error(y_train_tr, predictions_tr))
rmse_tr
# Out:
# 59.045357269722

# %%
# Models predicted price for X_test
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)

# %%
y_test.shape, predictions.shape
# Out:
# ((309, 1), (309, 1))

# %%
# RMSE to check accuracy

rmse = math.sqrt(mean_squared_error(y_test, predictions))
rmse
# Out:
# 82.59131209735249

# %%
# Plot
train = TSdata_df[:training_data_len]
actual = TSdata_df[training_data_len:]
actual['Predictions'] = predictions
actual
# Out:
# <ipython-input-38-bb86776ae978>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   actual['Predictions'] = predictions
#                   Close  Predictions
# Date
# 2020-07-07  1657.449951  1629.727539
# 2020-07-08  1661.300049  1643.223022
# 2020-07-09  1670.280029  1654.282227
# 2020-07-10  1707.400024  1663.649902
# 2020-07-13  1686.760010  1674.946167
# ...                 ...          ...
# 2021-09-20  2340.739990  2290.022217
# 2021-09-21  2325.620117  2289.404053
# 2021-09-22  2406.110107  2286.601318
# 2021-09-23  2475.510010  2293.549316
# 2021-09-24  2491.350098  2314.578369
#
# [309 rows x 2 columns]

# %%
plt.figure(figsize=(16,8))
plt.title(f"Model for '{stock}' - {ticker}")
plt.xlabel("Date")
plt.ylabel("Close Price USD")
plt.plot(train['Close'])
plt.plot(actual[['Close', 'Predictions']])
plt.legend(['Train', 'Actual', 'Predictions'], loc='lower right')
plt.savefig('Saved_Models/Images/'+ticker+'.png')
plt.show()

# %% [markdown]
# # TEST

# %%
# for predictions add 100 extra days to make sure it has more than ts_points to make up for missing days (weekends and holidays)

fetch_days = ts_points + 100    

sd =  today - timedelta(days=fetch_days)
sd = sd.strftime('%Y-%m-%d')

ed = today.strftime('%Y-%m-%d')
ed

next_day = (today + timedelta(days=1) ).strftime('%Y-%m-%d')
# next_day

# %%
# get the quote
quote = pdr.DataReader(ticker, data_source="yahoo", start=sd, end=ed)
new_df = quote.filter(['Close'])
last_n_days = ts_points
last_n_days_arr = new_df[-last_n_days:].values

# %%
last_n_days_scaled = scaler.transform(last_n_days_arr)
X_test = []
X_test.append(last_n_days_scaled)
X_test = np.array(X_test)
X_test = np.reshape(X_test,(X_test.shape[0], X_test.shape[1],1))

# %%
##########################loading saved model ###############################
new_model = tf.keras.models.load_model('Saved_Models/Model_'+ticker+'.h5')

# Check its architecture
new_model.summary()
nmpred_price = new_model.predict(X_test)
nmpred_price = scaler.inverse_transform(nmpred_price)
nmpred_price = nmpred_price[0][0]
print(f"Predicted Closing price for '{stock}' on {next_day} is {nmpred_price:.4f}")
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 120, 50)           10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dropout (Dropout)            (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 25)                1275
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 31,901
# Trainable params: 31,901
# Non-trainable params: 0
# _________________________________________________________________
# Predicted Closing price for 'Booking Holdings Inc' on 2021-10-26 is 2363.8169

# %%
pred_price = model.predict(X_test)
pred_price = scaler.inverse_transform(pred_price)
pred_price = pred_price[0][0]
print(f"Predicted Closing price for '{stock}' on {next_day} is {pred_price:.4f}")
# Out:
# Predicted Closing price for 'Booking Holdings Inc' on 2021-10-26 is 2363.8169

# %%
# verify
d1 = today - timedelta(days=5)
d1 = d1.strftime('%Y-%m-%d')

quote2 = pdr.DataReader(ticker, data_source="yahoo", start=d1)
quote2
# Out:
#                    High          Low         Open        Close  Volume  \
# Date
# 2021-10-20  2465.010010  2368.739990  2465.010010  2384.179932  406900
# 2021-10-21  2419.830078  2390.030029  2400.550049  2411.129883  212500
# 2021-10-22  2438.959961  2385.719971  2407.110107  2394.590088  161900
# 2021-10-25  2420.519287  2374.350098  2397.840088  2412.979980  142414
#
#               Adj Close
# Date
# 2021-10-20  2384.179932
# 2021-10-21  2411.129883
# 2021-10-22  2394.590088
# 2021-10-25  2412.979980
