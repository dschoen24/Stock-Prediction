# %%
import math
import numpy as np
import os
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas_datareader as pdr
from datetime import datetime, timedelta

# %%
#Get the stock
ticker = 'PTON'
stock ="Peloton Interactive Inc"
# Time step n days, here we will use n  days historical data to predict next day closing
ts_points = 120
# train_data[0:60,0]  

today = datetime.today()
# start_date ='2016-01-01'
start_date = (today - timedelta(days=5*365) ).strftime('%Y-%m-%d')

# end_date   = today.strftime('%Y-%m-%d')
end_date = (today - timedelta(days=31) ).strftime('%Y-%m-%d')

stock_df = pdr.DataReader(ticker, data_source="yahoo", start=start_date, end=end_date)

# %%
# Date is an index but to be sure , let's sort
stock_df = stock_df.sort_index(ascending=True)
stock_df
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2019-09-26   27.980000   24.750000   27.170000   25.760000  47067700
# 2019-09-27   26.170000   23.750000   26.170000   25.240000  15976000
# 2019-09-30   25.850000   25.000000   25.260000   25.100000   4482900
# 2019-10-01   25.170000   22.510000   25.000000   22.510000   8816100
# 2019-10-02   23.180000   21.760000   22.250000   22.600000   9454700
# ...                ...         ...         ...         ...       ...
# 2021-09-20  104.129997   99.300003  101.400002  100.730003   5282300
# 2021-09-21  103.930000  100.440002  101.250000  100.919998   3909900
# 2021-09-22   99.980003   92.610001   99.510002   94.550003  17075000
# 2021-09-23   96.570000   94.010002   94.809998   94.379997   5366900
# 2021-09-24   94.129997   91.760002   94.129997   92.639999   5244900
#
#              Adj Close
# Date
# 2019-09-26   25.760000
# 2019-09-27   25.240000
# 2019-09-30   25.100000
# 2019-10-01   22.510000
# 2019-10-02   22.600000
# ...                ...
# 2021-09-20  100.730003
# 2021-09-21  100.919998
# 2021-09-22   94.550003
# 2021-09-23   94.379997
# 2021-09-24   92.639999
#
# [504 rows x 6 columns]

# %%
# check for nulls
stock_df.isna().sum()
# Out:
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
# Get shape
stock_df.shape
# Out:
# (504, 6)

# %%
# Visualize closing price history
plt.figure(figsize=(16,8))
plt.title (f"Closing Price History for '{stock}' - {ticker}")
plt.plot(stock_df['Close'])
plt.xlabel('Date')
plt.ylabel('Close Price USD', fontsize=16)
#plt.savefig('Saved_Models/Images/his_'+ticker+'.png')
plt.show()

# %%
stock_df['Close'].plot.density()
plt.xlabel('Distribution of the closing stock price')
#plt.savefig('Saved_Models/Images/den_'+ticker+'.png')
plt.show()

# %%
# DF with only close
TSdata_df = stock_df.filter(['Close'])
TSdata_df
# Out:
#                  Close
# Date
# 2019-09-26   25.760000
# 2019-09-27   25.240000
# 2019-09-30   25.100000
# 2019-10-01   22.510000
# 2019-10-02   22.600000
# ...                ...
# 2021-09-20  100.730003
# 2021-09-21  100.919998
# 2021-09-22   94.550003
# 2021-09-23   94.379997
# 2021-09-24   92.639999
#
# [504 rows x 1 columns]

# %%
TSdata_arr = TSdata_df.values # this creates an array of Close Price
TSdata_arr
# Out:
# array([[ 25.76000023],
#        [ 25.23999977],
#        [ 25.10000038],
#        [ 22.51000023],
#        [ 22.60000038],
#        [ 22.32999992],
#        [ 23.01000023],
#        [ 23.51000023],
#        [ 23.20999908],
#        [ 24.        ],
#        [ 23.13999939],
#        [ 22.38999939],
#        [ 21.46999931],
#        [ 23.44499969],
#        [ 23.03000069],
#        [ 23.86000061],
#        [ 23.52000046],
#        [ 22.26000023],
#        [ 21.15999985],
#        [ 21.07999992],
#        [ 21.34000015],
#        [ 22.39999962],
#        [ 21.45999908],
#        [ 23.18000031],
#        [ 23.71999931],
#        [ 23.87000084],
#        [ 24.98999977],
#        [ 24.61000061],
#        [ 22.73999977],
#        [ 23.02000046],
#        [ 22.62999916],
#        [ 23.52000046],
#        [ 24.04000092],
#        [ 24.69000053],
#        [ 25.97999954],
#        [ 25.93000031],
#        [ 27.22999954],
#        [ 30.25      ],
#        [ 29.23999977],
#        [ 29.10000038],
#        [ 29.79999924],
#        [ 29.36000061],
#        [ 30.87000084],
#        [ 30.95999908],
#        [ 32.15999985],
#        [ 35.22999954],
#        [ 36.84000015],
#        [ 33.47999954],
#        [ 32.95999908],
#        [ 31.30999947],
#        [ 32.63000107],
#        [ 34.77000046],
#        [ 32.77999878],
#        [ 32.02999878],
#        [ 30.85000038],
#        [ 31.53000069],
#        [ 31.34000015],
#        [ 32.93000031],
#        [ 31.88999939],
#        [ 31.93000031],
#        [ 29.98999977],
#        [ 29.21999931],
#        [ 28.75      ],
#        [ 27.        ],
#        [ 27.        ],
#        [ 27.69000053],
#        [ 28.39999962],
#        [ 29.73999977],
#        [ 30.60000038],
#        [ 29.75      ],
#        [ 30.39999962],
#        [ 29.64999962],
#        [ 27.87000084],
#        [ 28.01000023],
#        [ 28.53000069],
#        [ 29.69000053],
#        [ 30.86000061],
#        [ 30.82999992],
#        [ 31.70000076],
#        [ 32.        ],
#        [ 30.68000031],
#        [ 30.05999947],
#        [ 30.5       ],
#        [ 31.25      ],
#        [ 31.37999916],
#        [ 31.5       ],
#        [ 32.25999832],
#        [ 32.36000061],
#        [ 33.36999893],
#        [ 33.47000122],
#        [ 32.70000076],
#        [ 29.        ],
#        [ 27.86000061],
#        [ 28.60000038],
#        [ 28.64999962],
#        [ 28.34000015],
#        [ 28.85000038],
#        [ 27.65999985],
#        [ 27.07999992],
#        [ 27.10000038],
#        [ 26.97999954],
#        [ 25.48999977],
#        [ 26.5       ],
#        [ 27.11000061],
#        [ 29.19000053],
#        [ 28.71999931],
#        [ 26.69000053],
#        [ 27.92000008],
#        [ 26.68499947],
#        [ 27.25      ],
#        [ 27.10000038],
#        [ 24.97999954],
#        [ 23.20999908],
#        [ 22.96999931],
#        [ 22.        ],
#        [ 19.51000023],
#        [ 19.71999931],
#        [ 22.25      ],
#        [ 25.45000076],
#        [ 25.79000092],
#        [ 24.98999977],
#        [ 23.01000023],
#        [ 23.34000015],
#        [ 24.56999969],
#        [ 24.52000046],
#        [ 25.75      ],
#        [ 25.97999954],
#        [ 27.70000076],
#        [ 26.54999924],
#        [ 27.95999908],
#        [ 26.73999977],
#        [ 28.75      ],
#        [ 28.37000084],
#        [ 27.57999992],
#        [ 27.5       ],
#        [ 28.45000076],
#        [ 31.98999977],
#        [ 31.87999916],
#        [ 35.61000061],
#        [ 36.34999847],
#        [ 33.49000168],
#        [ 31.06999969],
#        [ 31.38999939],
#        [ 31.18000031],
#        [ 29.88999939],
#        [ 31.73999977],
#        [ 31.78000069],
#        [ 30.        ],
#        [ 31.88999939],
#        [ 31.5       ],
#        [ 32.04999924],
#        [ 33.90000153],
#        [ 36.22000122],
#        [ 38.02999878],
#        [ 44.11999893],
#        [ 43.        ],
#        [ 42.79999924],
#        [ 46.16999817],
#        [ 45.16999817],
#        [ 45.11000061],
#        [ 48.41999817],
#        [ 43.61000061],
#        [ 44.79999924],
#        [ 45.11000061],
#        [ 45.29999924],
#        [ 45.81000137],
#        [ 41.70000076],
#        [ 41.06999969],
#        [ 42.61000061],
#        [ 42.18999863],
#        [ 45.84999847],
#        [ 49.00999832],
#        [ 47.83000183],
#        [ 47.88000107],
#        [ 45.90000153],
#        [ 44.77999878],
#        [ 47.63999939],
#        [ 47.11000061],
#        [ 45.97999954],
#        [ 47.09999847],
#        [ 49.93999863],
#        [ 49.90999985],
#        [ 49.16999817],
#        [ 51.08000183],
#        [ 50.88999939],
#        [ 53.02999878],
#        [ 54.88000107],
#        [ 55.54999924],
#        [ 58.06000137],
#        [ 58.43000031],
#        [ 57.20999908],
#        [ 57.77000046],
#        [ 60.25      ],
#        [ 59.15999985],
#        [ 60.47999954],
#        [ 60.81999969],
#        [ 62.52000046],
#        [ 64.48999786],
#        [ 68.47000122],
#        [ 61.58000183],
#        [ 62.95000076],
#        [ 63.13000107],
#        [ 61.29000092],
#        [ 58.52999878],
#        [ 64.70999908],
#        [ 62.88000107],
#        [ 64.13999939],
#        [ 62.31000137],
#        [ 61.81999969],
#        [ 63.68000031],
#        [ 64.11000061],
#        [ 66.65000153],
#        [ 65.27999878],
#        [ 68.22000122],
#        [ 72.68000031],
#        [ 70.01000214],
#        [ 71.20999908],
#        [ 69.72000122],
#        [ 68.30000305],
#        [ 67.12000275],
#        [ 64.95999908],
#        [ 64.36000061],
#        [ 65.70999908],
#        [ 64.33999634],
#        [ 65.26000214],
#        [ 69.81999969],
#        [ 67.58999634],
#        [ 68.72000122],
#        [ 69.34999847],
#        [ 66.87000275],
#        [ 66.44999695],
#        [ 67.30000305],
#        [ 70.30000305],
#        [ 75.95999908],
#        [ 76.66999817],
#        [ 83.66999817],
#        [ 91.05999756],
#        [ 82.27999878],
#        [ 80.62999725],
#        [ 85.59999847],
#        [ 91.16999817],
#        [ 87.75      ],
#        [ 84.04000092],
#        [ 82.01000214],
#        [ 85.44999695],
#        [ 82.58999634],
#        [ 85.19999695],
#        [ 89.69999695],
#        [ 94.80000305],
#        [ 94.38999939],
#        [ 95.23000336],
#        [ 88.55999756],
#        [ 97.73000336],
#        [ 96.91000366],
#        [100.47000122],
#        [ 99.23999786],
#        [105.19999695],
#        [107.51000214],
#        [110.73999786],
#        [111.30999756],
#        [116.95999908],
#        [115.        ],
#        [123.01999664],
#        [127.30000305],
#        [130.97000122],
#        [131.44000244],
#        [136.42999268],
#        [131.33000183],
#        [133.00999451],
#        [131.92999268],
#        [124.30000305],
#        [120.80000305],
#        [122.52999878],
#        [118.09999847],
#        [121.15000153],
#        [122.12000275],
#        [115.91000366],
#        [110.20999908],
#        [113.44000244],
#        [111.69999695],
#        [118.59999847],
#        [126.62999725],
#        [125.45999908],
#        [100.01000214],
#        [105.20999908],
#        [106.20999908],
#        [108.72000122],
#        [100.79000092],
#        [101.90000153],
#        [102.48999786],
#        [104.48999786],
#        [105.26000214],
#        [110.90000153],
#        [112.05000305],
#        [105.41999817],
#        [106.94000244],
#        [108.98000336],
#        [116.34999847],
#        [112.02999878],
#        [113.18000031],
#        [116.19999695],
#        [114.44999695],
#        [116.62999725],
#        [118.25      ],
#        [110.79000092],
#        [117.98999786],
#        [117.09999847],
#        [121.91000366],
#        [127.77999878],
#        [134.        ],
#        [136.80000305],
#        [139.83999634],
#        [144.38999939],
#        [161.21000671],
#        [162.75999451],
#        [162.72000122],
#        [152.17999268],
#        [150.1000061 ],
#        [154.96000671],
#        [151.72000122],
#        [145.96000671],
#        [148.52999878],
#        [143.75999451],
#        [154.        ],
#        [158.88000488],
#        [152.33999634],
#        [156.03999329],
#        [167.41999817],
#        [165.25      ],
#        [157.80999756],
#        [150.13999939],
#        [155.78999329],
#        [158.13000488],
#        [159.75      ],
#        [157.13999939],
#        [147.78999329],
#        [144.96000671],
#        [145.83000183],
#        [146.13000488],
#        [146.78999329],
#        [147.72999573],
#        [147.16999817],
#        [157.52999878],
#        [148.30000305],
#        [144.99000549],
#        [147.75999451],
#        [145.03999329],
#        [146.47999573],
#        [154.66999817],
#        [145.88000488],
#        [139.22999573],
#        [138.44999695],
#        [139.71000671],
#        [125.75      ],
#        [126.88999939],
#        [122.72000122],
#        [115.20999908],
#        [120.47000122],
#        [123.80999756],
#        [117.97000122],
#        [108.08000183],
#        [104.75      ],
#        [105.12999725],
#        [101.34999847],
#        [116.01999664],
#        [111.31999969],
#        [117.65000153],
#        [111.55000305],
#        [112.73999786],
#        [107.95999908],
#        [107.79000092],
#        [102.73999786],
#        [108.30999756],
#        [109.54000092],
#        [113.34999847],
#        [101.79000092],
#        [103.23000336],
#        [106.41999817],
#        [105.01999664],
#        [107.16999817],
#        [112.44000244],
#        [112.08999634],
#        [109.08999634],
#        [115.37999725],
#        [115.19999695],
#        [123.62000275],
#        [118.59999847],
#        [118.97000122],
#        [122.36000061],
#        [117.80000305],
#        [119.90000153],
#        [116.20999908],
#        [107.75      ],
#        [106.5       ],
#        [ 99.93000031],
#        [101.48999786],
#        [101.06999969],
#        [103.26999664],
#        [102.33999634],
#        [103.22000122],
#        [ 98.90000153],
#        [ 98.34999847],
#        [ 95.83999634],
#        [ 96.69999695],
#        [ 82.62000275],
#        [ 83.77999878],
#        [ 83.80999756],
#        [ 87.48999786],
#        [ 91.01000214],
#        [ 89.34999847],
#        [ 95.29000092],
#        [ 96.58000183],
#        [ 92.29000092],
#        [ 95.19000244],
#        [ 96.55000305],
#        [100.45999908],
#        [100.90000153],
#        [101.16000366],
#        [ 99.44000244],
#        [109.55999756],
#        [112.59999847],
#        [110.30999756],
#        [108.88999939],
#        [108.55000305],
#        [103.09999847],
#        [103.01000214],
#        [109.79000092],
#        [109.69000244],
#        [106.97000122],
#        [106.08000183],
#        [113.12000275],
#        [112.08999634],
#        [106.11000061],
#        [105.06999969],
#        [108.80999756],
#        [109.12000275],
#        [108.11000061],
#        [117.16999817],
#        [117.48000336],
#        [121.84999847],
#        [121.48999786],
#        [126.91999817],
#        [125.68000031],
#        [124.01999664],
#        [122.16000366],
#        [121.59999847],
#        [123.69000244],
#        [123.51000214],
#        [124.05999756],
#        [117.83999634],
#        [120.30999756],
#        [119.84999847],
#        [113.36000061],
#        [111.19000244],
#        [110.54000092],
#        [118.43000031],
#        [126.34999847],
#        [126.43000031],
#        [119.66999817],
#        [121.55000305],
#        [122.68000031],
#        [121.36000061],
#        [121.91999817],
#        [118.09999847],
#        [118.05000305],
#        [120.69000244],
#        [119.26999664],
#        [120.93000031],
#        [120.22000122],
#        [112.69000244],
#        [116.58000183],
#        [113.83999634],
#        [112.94999695],
#        [112.63999939],
#        [110.87999725],
#        [110.        ],
#        [113.25      ],
#        [110.65000153],
#        [107.80000305],
#        [108.06999969],
#        [106.58999634],
#        [113.70999908],
#        [116.25      ],
#        [114.08999634],
#        [104.33999634],
#        [101.48000336],
#        [100.19000244],
#        [100.04000092],
#        [101.        ],
#        [ 98.55999756],
#        [ 96.48000336],
#        [ 97.5       ],
#        [107.08000183],
#        [114.38999939],
#        [111.51000214],
#        [108.5       ],
#        [105.55999756],
#        [104.91999817],
#        [103.41999817],
#        [100.73000336],
#        [100.91999817],
#        [ 94.55000305],
#        [ 94.37999725],
#        [ 92.63999939]])

# %%
from statsmodels.tsa.stattools import adfuller
import pandas as pd
import numpy as np

# ADF Test
result = adfuller(TSdata_arr, autolag='AIC')

print('ADF Statistic: %f' % result[0])

print('p-value: %f' % result[1])

print('Critical Values:')

for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
if result[0] < result[4]["5%"]:
    print ("Reject Ho - Time Series is Stationary")
else:
    print ("Failed to Reject Ho - Time Series is Non-Stationary")
# Out:
# ADF Statistic: -1.399188
# p-value: 0.582665
# Critical Values:
# 	1%: -3.444
# 	5%: -2.867
# 	10%: -2.570
# Failed to Reject Ho - Time Series is Non-Stationary

# %%
df2 = TSdata_df['Close'].diff().dropna().to_frame()
df2
# Out:
#                Close
# Date
# 2019-09-27 -0.520000
# 2019-09-30 -0.139999
# 2019-10-01 -2.590000
# 2019-10-02  0.090000
# 2019-10-03 -0.270000
# ...              ...
# 2021-09-20 -2.689995
# 2021-09-21  0.189995
# 2021-09-22 -6.369995
# 2021-09-23 -0.170006
# 2021-09-24 -1.739998
#
# [503 rows x 1 columns]

# %%
# Visualize closing price history
plt.figure(figsize=(16,8))
plt.title (f"Closing Price History for '{stock}' - {ticker}")
plt.plot(df2['Close'])
plt.xlabel('Date')
plt.ylabel('Close Price USD', fontsize=16)
#plt.savefig('Saved_Models/Images/diff_'+ticker+'.png')
plt.show()

# %%
# TSdata_arr = df2.filter(['Close']).values
# TSdata_arr

# %%
# Scale the Data
scaler = MinMaxScaler(feature_range =(0,1))
scaled_data = scaler.fit_transform(TSdata_arr)
# scaled_data

# %%
training_data_len = math.ceil(len(TSdata_arr) * 0.75)
training_data_len
# Out:
# 378

# %%
# Created scaled training dataset
train_data = scaled_data[0:training_data_len]
train_data.shape
# Out:
# (378, 1)

# %%
# Split
X_train = []
y_train = []

for i in range(ts_points, len(train_data)):
    X_train.append(train_data[i-ts_points:i,0])
    y_train.append(train_data[i,0])
    # if i <= ts_points+3:
    #     print(X_train)
    #     print(y_train)
    #     print()

# %%
# convert X_train and y_train to numpy arrays for LSTM
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
print (X_train.shape)
print (y_train.shape)
# Out:
# (258, 120)
# (258,)

# %%
# LSTM network expects a 3D input (No_of_Samples, number of time steps, and number of features) no_of_features = 1 (Close)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_train.shape
# Out:
# (258, 120, 1)

# %%
training_data_len - ts_points
# Out:
# 258

# %%
# hidden_nodes = int(2/3 * (X_train.shape[1] * 1))
# print(f"The number of hidden nodes is {hidden_nodes}.")

# %%
# LSTM MOdel
model = tf.keras.models.Sequential()
# model.add(tf.keras.layers.LSTM(50, return_sequences=True, input_shape=(X_train.shape[1],1)))
# model.add(tf.keras.layers.LSTM(50, return_sequences=False))
# model.add(tf.keras.layers.Dropout(0.2))
# model.add(tf.keras.layers.Dense(25))
# model.add(tf.keras.layers.Dense(1))
# model.summary()

# %%
# # BEST FOR PTON#
model.add(tf.keras.layers.LSTM(50, return_sequences=True, input_shape=(X_train.shape[1],1)))
model.add(tf.keras.layers.LSTM(50, return_sequences=False))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(25))
model.add(tf.keras.layers.Dense(1))
model.summary()

# #model.fit(X_train, y_train, batch_size=64, epochs=50
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 120, 50)           10400
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 25)                1275
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 31,901
# Trainable params: 31,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
# model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
import os
from tensorflow.keras.callbacks import ModelCheckpoint

batch_size=64

os.makedirs("chk_points/", exist_ok=True)
chkpoint_path="chk_points/weights.{epoch}.hdf5"

# Create chk points
chkpt_callback = ModelCheckpoint(filepath=chkpoint_path,
                              verbose=1,
                              save_weights_only=True,
                              save_freq="epoch",
                              period=5)

# chkpoint_path = "chk_points/cp-{epoch:04d}.ckpt"
# chkpt_callback = tf.keras.callbacks.ModelCheckpoint(
#     filepath=chkpoint_path, 
#     verbose=1, 
#     save_weights_only=True,
#     save_freq=5*batch_size)                    

# model.save_weights(chkpoint_path.format(epoch=0))
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# training_data_len
# scaled_data

# %%
# model.fit(X_train, y_train, batch_size=batch_size, epochs=50, validation_split=0.43, callbacks=[chkpt_callback])
model.fit(X_train, y_train, batch_size=64 ,epochs=92)
# Out:
# Epoch 1/92
# 5/5 [==============================] - 4s 72ms/step - loss: 0.2079
# Epoch 2/92
# 5/5 [==============================] - 0s 68ms/step - loss: 0.0327
# Epoch 3/92
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0238
# Epoch 4/92
# 5/5 [==============================] - 0s 63ms/step - loss: 0.0209
# Epoch 5/92
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0177
# Epoch 6/92
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0109
# Epoch 7/92
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0164
# Epoch 8/92
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0098
# Epoch 9/92
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0114
# Epoch 10/92
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0084
# Epoch 11/92
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0085
# Epoch 12/92
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0082
# Epoch 13/92
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0076
# Epoch 14/92
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0062
# Epoch 15/92
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0068
# Epoch 16/92
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0070
# Epoch 17/92
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0062
# Epoch 18/92
# 5/5 [==============================] - 1s 92ms/step - loss: 0.0076
# Epoch 19/92
# 5/5 [==============================] - 1s 106ms/step - loss: 0.0051
# Epoch 20/92
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0072
# Epoch 21/92
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0055
# Epoch 22/92
# 5/5 [==============================] - 0s 103ms/step - loss: 0.0054
# Epoch 23/92
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0057
# Epoch 24/92
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0070
# Epoch 25/92
# 5/5 [==============================] - 1s 99ms/step - loss: 0.0059
# Epoch 26/92
# 5/5 [==============================] - 1s 143ms/step - loss: 0.0060
# Epoch 27/92
# 5/5 [==============================] - 1s 108ms/step - loss: 0.0050
# Epoch 28/92
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0049
# Epoch 29/92
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0049
# Epoch 30/92
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0042
# Epoch 31/92
# 5/5 [==============================] - 1s 119ms/step - loss: 0.0044
# Epoch 32/92
# 5/5 [==============================] - 1s 115ms/step - loss: 0.0063
# Epoch 33/92
# 5/5 [==============================] - 1s 100ms/step - loss: 0.0050
# Epoch 34/92
# 5/5 [==============================] - 1s 120ms/step - loss: 0.0070
# Epoch 35/92
# 5/5 [==============================] - 1s 110ms/step - loss: 0.0051
# Epoch 36/92
# 5/5 [==============================] - 1s 117ms/step - loss: 0.0057
# Epoch 37/92
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0049
# Epoch 38/92
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0048
# Epoch 39/92
# 5/5 [==============================] - 1s 198ms/step - loss: 0.0051
# Epoch 40/92
# 5/5 [==============================] - 1s 194ms/step - loss: 0.0052
# Epoch 41/92
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0059
# Epoch 42/92
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0044
# Epoch 43/92
# 5/5 [==============================] - 1s 115ms/step - loss: 0.0040
# Epoch 44/92
# 5/5 [==============================] - 1s 131ms/step - loss: 0.0057
# Epoch 45/92
# 5/5 [==============================] - 1s 119ms/step - loss: 0.0046
# Epoch 46/92
# 5/5 [==============================] - 1s 113ms/step - loss: 0.0053
# Epoch 47/92
# 5/5 [==============================] - 1s 113ms/step - loss: 0.0042
# Epoch 48/92
# 5/5 [==============================] - 1s 118ms/step - loss: 0.0039
# Epoch 49/92
# 5/5 [==============================] - 1s 122ms/step - loss: 0.0044
# Epoch 50/92
# 5/5 [==============================] - 1s 108ms/step - loss: 0.0039
# Epoch 51/92
# 5/5 [==============================] - 1s 116ms/step - loss: 0.0044
# Epoch 52/92
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0042
# Epoch 53/92
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0039
# Epoch 54/92
# 5/5 [==============================] - 1s 100ms/step - loss: 0.0043
# Epoch 55/92
# 5/5 [==============================] - 1s 133ms/step - loss: 0.0037
# Epoch 56/92
# 5/5 [==============================] - 0s 101ms/step - loss: 0.0037
# Epoch 57/92
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0037
# Epoch 58/92
# 5/5 [==============================] - 1s 105ms/step - loss: 0.0045
# Epoch 59/92
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0041
# Epoch 60/92
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0035
# Epoch 61/92
# 5/5 [==============================] - 1s 120ms/step - loss: 0.0039
# Epoch 62/92
# 5/5 [==============================] - 1s 114ms/step - loss: 0.0037
# Epoch 63/92
# 5/5 [==============================] - 1s 98ms/step - loss: 0.0036
# Epoch 64/92
# 5/5 [==============================] - 1s 113ms/step - loss: 0.0032
# Epoch 65/92
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0049
# Epoch 66/92
# 5/5 [==============================] - 1s 102ms/step - loss: 0.0046
# Epoch 67/92
# 5/5 [==============================] - 1s 106ms/step - loss: 0.0039
# Epoch 68/92
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0044
# Epoch 69/92
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0030
# Epoch 70/92
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0040
# Epoch 71/92
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0061
# Epoch 72/92
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0041
# Epoch 73/92
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0045
# Epoch 74/92
# 5/5 [==============================] - 0s 97ms/step - loss: 0.0053
# Epoch 75/92
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0038
# Epoch 76/92
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0036
# Epoch 77/92
# 5/5 [==============================] - 1s 152ms/step - loss: 0.0036
# Epoch 78/92
# 5/5 [==============================] - 1s 140ms/step - loss: 0.0035
# Epoch 79/92
# 5/5 [==============================] - 1s 131ms/step - loss: 0.0037
# Epoch 80/92
# 5/5 [==============================] - 1s 149ms/step - loss: 0.0031
# Epoch 81/92
# 5/5 [==============================] - 1s 117ms/step - loss: 0.0039
# Epoch 82/92
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0043
# Epoch 83/92
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0043
# Epoch 84/92
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0035
# Epoch 85/92
# 5/5 [==============================] - 1s 160ms/step - loss: 0.0036
# Epoch 86/92
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0035
# Epoch 87/92
# 5/5 [==============================] - 1s 123ms/step - loss: 0.0038
# Epoch 88/92
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0040
# Epoch 89/92
# 5/5 [==============================] - 1s 158ms/step - loss: 0.0043
# Epoch 90/92
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0041
# Epoch 91/92
# 5/5 [==============================] - 1s 102ms/step - loss: 0.0037
# Epoch 92/92
# 5/5 [==============================] - 1s 105ms/step - loss: 0.0035

# %%
#model.save('Saved_Models/Model_'+ticker+'.h5')

# %%
# test_data = scaled_data[training_data_len:]

# Bring in the last 'ts_points' (60 values) from training set so when X_test is used to predict , predictions have same shape as Y_test
# The for loop starts with 'ts_points' thatbmeans the resultant array will have 60 less rows
test_data = scaled_data[training_data_len-ts_points:]
# test_data[0:60,0]

# %%
X_test = []
y_test = TSdata_arr[training_data_len:]
for i in range(ts_points, len(test_data)):
    X_test.append(test_data[i-ts_points:i,0])

# %%
# convert the data to a numpy array to use it in LSTM MODEL
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],  X_test.shape[1], 1))

# %%
from sklearn.metrics import mean_squared_error

# %%
# Models predicted price for X_train
predictions_tr = model.predict(X_train)
predictions_tr = scaler.inverse_transform(predictions_tr)

y_train_tr =  scaler.inverse_transform(y_train.reshape(-1,1))
rmse_tr = math.sqrt(mean_squared_error(y_train_tr, predictions_tr))
rmse_tr
# Out:
# 6.9522066721914175

# %%
# Models predicted price for X_test
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)

# %%
y_test.shape, predictions.shape
# Out:
# ((126, 1), (126, 1))

# %%
# RMSE to check accuracy

rmse = math.sqrt(mean_squared_error(y_test, predictions))
rmse
# Out:
# 6.71664098744204

# %%
# Plot
train = TSdata_df[:training_data_len]
actual = TSdata_df[training_data_len:]
actual['Predictions'] = predictions
actual
# Out:
# <ipython-input-77-bb86776ae978>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   actual['Predictions'] = predictions
#                  Close  Predictions
# Date
# 2021-03-29  105.019997   108.314674
# 2021-03-30  107.169998   107.878883
# 2021-03-31  112.440002   107.642647
# 2021-04-01  112.089996   107.983673
# 2021-04-05  109.089996   108.638397
# ...                ...          ...
# 2021-09-20  100.730003   107.236542
# 2021-09-21  100.919998   107.061844
# 2021-09-22   94.550003   106.582016
# 2021-09-23   94.379997   105.415024
# 2021-09-24   92.639999   103.888771
#
# [126 rows x 2 columns]

# %%
plt.figure(figsize=(16,8))
plt.title(f"Model for '{stock}' - {ticker}")
plt.xlabel("Date")
plt.ylabel("Close Price USD")
plt.plot(train['Close'])
plt.plot(actual[['Close', 'Predictions']])
plt.legend(['Train', 'Actual', 'Predictions'], loc='lower right')
#plt.savefig('Saved_Models/Images/'+ticker+'.png')
plt.show()

# %% [markdown]
# # TEST

# %%
# for predictions add 100 extra days to make sure it has more than ts_points to make up for missing days (weekends and holidays)

fetch_days = ts_points + 100    

sd =  today - timedelta(days=fetch_days)
sd = sd.strftime('%Y-%m-%d')

ed = today.strftime('%Y-%m-%d')
ed

next_day = (today + timedelta(days=1) ).strftime('%Y-%m-%d')
# next_day

# %%
# get the quote
quote = pdr.DataReader(ticker, data_source="yahoo", start=sd, end=ed)
new_df = quote.filter(['Close'])
last_n_days = ts_points
last_n_days_arr = new_df[-last_n_days:].values

# %%
last_n_days_scaled = scaler.transform(last_n_days_arr)
X_test = []
X_test.append(last_n_days_scaled)
X_test = np.array(X_test)
X_test = np.reshape(X_test,(X_test.shape[0], X_test.shape[1],1))

# %%
##########################loading saved model ###############################
new_model = tf.keras.models.load_model('Saved_Models/Model_'+ticker+'.h5')

# Check its architecture
new_model.summary()
nmpred_price = new_model.predict(X_test)
nmpred_price = scaler.inverse_transform(nmpred_price)
nmpred_price = nmpred_price[0][0]
print(f"Predicted Closing price for '{stock}' on {next_day} is {nmpred_price:.4f}")
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 120, 50)           10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dropout (Dropout)            (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 25)                1275
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 31,901
# Trainable params: 31,901
# Non-trainable params: 0
# _________________________________________________________________
# Predicted Closing price for 'Peloton Interactive Inc' on 2021-10-26 is 96.0543

# %%
pred_price = model.predict(X_test)
pred_price = scaler.inverse_transform(pred_price)
pred_price = pred_price[0][0]
print(f"Predicted Closing price for '{stock}' on {next_day} is {pred_price:.4f}")
# Out:
# Predicted Closing price for 'Peloton Interactive Inc' on 2021-10-26 is 92.5461

# %%
# verify
d1 = today - timedelta(days=5)
d1 = d1.strftime('%Y-%m-%d')

quote2 = pdr.DataReader(ticker, data_source="yahoo", start=d1)
quote2
# Out:
#                  High        Low       Open      Close   Volume  Adj Close
# Date
# 2021-10-20  93.750000  89.779999  91.410004  90.650002  9689600  90.650002
# 2021-10-21  95.589996  90.349998  90.410004  94.830002  7021600  94.830002
# 2021-10-22  94.904999  92.180000  93.954002  93.830002  3920300  93.830002
# 2021-10-25  97.529999  93.290001  93.500000  96.599998  5710800  96.599998
